# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os

# %%
pwd
# Out:
# 'C:\\Users\\Franklin'

# %%
os.chdir('C:\\Users\Franklin\Desktop\python')

# %%
df=pd.read_csv(r'produce.csv')
df
# Out:
#                                            Particulars  \
# 0                   Agricultural Production Foodgrains
# 1            Agricultural Production Foodgrains Kharif
# 2              Agricultural Production Foodgrains Rabi
# 3              Agricultural Production Foodgrains Rice
# 4       Agricultural Production Foodgrains Rice Kharif
# ..                                                 ...
# 424  Agricultural Production Foodgrains Coarse Cere...
# 425  Agricultural Production Foodgrains Coarse Cere...
# 426  Agricultural Production Foodgrains Coarse Cere...
# 427  Agricultural Production Foodgrains Coarse Cere...
# 428  Agricultural Production Foodgrains Coarse Cere...
#
#                            Frequency    Unit   3-1993   3-1994   3-1995  \
# 0    Annual, Ending mar Of Each Year  Ton mn      NaN      NaN      NaN
# 1    Annual, Ending mar Of Each Year  Ton mn      NaN      NaN      NaN
# 2    Annual, Ending mar Of Each Year  Ton mn      NaN      NaN      NaN
# ...

# %%
# Data exploration

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 429 entries, 0 to 428
# Data columns (total 25 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Particulars  429 non-null    object
#  1   Frequency    429 non-null    object
#  2   Unit         429 non-null    object
#  3    3-1993      3 non-null      float64
#  4    3-1994      4 non-null      float64
#  5    3-1995      4 non-null      float64
#  6    3-1996      6 non-null      float64
#  7    3-1997      10 non-null     float64
#  8    3-1998      10 non-null     float64
#  9    3-1999      11 non-null     float64
#  10   3-2000      20 non-null     float64
#  11   3-2001      22 non-null     float64
#  12   3-2002      36 non-null     float64
#  13   3-2003      128 non-null    float64
#  14   3-2004      361 non-null    float64
#  15   3-2005      425 non-null    float64
#  16   3-2006      423 non-null    float64
#  17   3-2007      418 non-null    float64
# ...

# %%
df.isnull().sum()
# Out:
# Particulars      0
# Frequency        0
# Unit             0
#  3-1993        426
#  3-1994        425
#  3-1995        425
#  3-1996        423
#  3-1997        419
#  3-1998        419
#  3-1999        418
#  3-2000        409
#  3-2001        407
#  3-2002        393
#  3-2003        301
#  3-2004         68
#  3-2005          4
#  3-2006          6
#  3-2007         11
#  3-2008         12
#  3-2009         11
#  3-2010         26
#  3-2011         25
#  3-2012         41
#  3-2013        131
#  3-2014        366
# dtype: int64

# %%
df.nunique()
# Out:
# Particulars    429
# Frequency        1
# Unit             7
#  3-1993          1
#  3-1994          1
#  3-1995          1
#  3-1996          3
#  3-1997          6
#  3-1998          7
#  3-1999          7
#  3-2000         15
#  3-2001         19
#  3-2002         32
#  3-2003        113
#  3-2004        341
#  3-2005        402
#  3-2006        416
#  3-2007        400
#  3-2008        401
#  3-2009        406
#  3-2010        393
#  3-2011        392
#  3-2012        379
#  3-2013        284
#  3-2014         63
# dtype: int64

# %%
# Data cleaning

# %%
pd.set_option('display.float_format', lambda s: '%.2f'%s)
df
# Out:
#                                            Particulars  \
# 0                   Agricultural Production Foodgrains
# 1            Agricultural Production Foodgrains Kharif
# 2              Agricultural Production Foodgrains Rabi
# 3              Agricultural Production Foodgrains Rice
# 4       Agricultural Production Foodgrains Rice Kharif
# ..                                                 ...
# 424  Agricultural Production Foodgrains Coarse Cere...
# 425  Agricultural Production Foodgrains Coarse Cere...
# 426  Agricultural Production Foodgrains Coarse Cere...
# 427  Agricultural Production Foodgrains Coarse Cere...
# 428  Agricultural Production Foodgrains Coarse Cere...
#
#                            Frequency    Unit   3-1993   3-1994   3-1995  \
# 0    Annual, Ending mar Of Each Year  Ton mn      NaN      NaN      NaN
# 1    Annual, Ending mar Of Each Year  Ton mn      NaN      NaN      NaN
# 2    Annual, Ending mar Of Each Year  Ton mn      NaN      NaN      NaN
# ...

# %%
df.columns
# Out:
# Index(['Particulars', 'Frequency', 'Unit', ' 3-1993', ' 3-1994', ' 3-1995',
#        ' 3-1996', ' 3-1997', ' 3-1998', ' 3-1999', ' 3-2000', ' 3-2001',
#        ' 3-2002', ' 3-2003', ' 3-2004', ' 3-2005', ' 3-2006', ' 3-2007',
#        ' 3-2008', ' 3-2009', ' 3-2010', ' 3-2011', ' 3-2012', ' 3-2013',
#        ' 3-2014'],
#       dtype='object')

# %%
df.rename(columns={' 3-1993':'1993', ' 3-1994':'1994', ' 3-1995':'1995',
       ' 3-1996':'1996', ' 3-1997':'1997', ' 3-1998':'1998', ' 3-1999':'1999', ' 3-2000':'2000', ' 3-2001':'2001',
       ' 3-2002':'2002', ' 3-2003':'2003', ' 3-2004':'2004', ' 3-2005':'2005', ' 3-2006':'2006', ' 3-2007':'2007',
       ' 3-2008':'2008', ' 3-2009':'2009', ' 3-2010':'2010', ' 3-2011':'2011', ' 3-2012':'2012', ' 3-2013':'2013',
       ' 3-2014':'2014'}, inplace=True)
df
# Out:
#                                            Particulars  \
# 0                   Agricultural Production Foodgrains
# 1            Agricultural Production Foodgrains Kharif
# 2              Agricultural Production Foodgrains Rabi
# 3              Agricultural Production Foodgrains Rice
# 4       Agricultural Production Foodgrains Rice Kharif
# ..                                                 ...
# 424  Agricultural Production Foodgrains Coarse Cere...
# 425  Agricultural Production Foodgrains Coarse Cere...
# 426  Agricultural Production Foodgrains Coarse Cere...
# 427  Agricultural Production Foodgrains Coarse Cere...
# 428  Agricultural Production Foodgrains Coarse Cere...
#
#                            Frequency    Unit  1993  1994  1995  1996  1997  \
# 0    Annual, Ending mar Of Each Year  Ton mn   NaN   NaN   NaN   NaN   NaN
# 1    Annual, Ending mar Of Each Year  Ton mn   NaN   NaN   NaN   NaN   NaN
# 2    Annual, Ending mar Of Each Year  Ton mn   NaN   NaN   NaN   NaN   NaN
# ...

# %%
df=df.drop_duplicates()
df
# Out:
#                                            Particulars  \
# 0                   Agricultural Production Foodgrains
# 1            Agricultural Production Foodgrains Kharif
# 2              Agricultural Production Foodgrains Rabi
# 3              Agricultural Production Foodgrains Rice
# 4       Agricultural Production Foodgrains Rice Kharif
# ..                                                 ...
# 424  Agricultural Production Foodgrains Coarse Cere...
# 425  Agricultural Production Foodgrains Coarse Cere...
# 426  Agricultural Production Foodgrains Coarse Cere...
# 427  Agricultural Production Foodgrains Coarse Cere...
# 428  Agricultural Production Foodgrains Coarse Cere...
#
#                            Frequency    Unit  1993  1994  1995  1996  1997  \
# 0    Annual, Ending mar Of Each Year  Ton mn   NaN   NaN   NaN   NaN   NaN
# 1    Annual, Ending mar Of Each Year  Ton mn   NaN   NaN   NaN   NaN   NaN
# 2    Annual, Ending mar Of Each Year  Ton mn   NaN   NaN   NaN   NaN   NaN
# ...

# %%
df=df.fillna('')
df
# Out:
#                                            Particulars  \
# 0                   Agricultural Production Foodgrains
# 1            Agricultural Production Foodgrains Kharif
# 2              Agricultural Production Foodgrains Rabi
# 3              Agricultural Production Foodgrains Rice
# 4       Agricultural Production Foodgrains Rice Kharif
# ..                                                 ...
# 424  Agricultural Production Foodgrains Coarse Cere...
# 425  Agricultural Production Foodgrains Coarse Cere...
# 426  Agricultural Production Foodgrains Coarse Cere...
# 427  Agricultural Production Foodgrains Coarse Cere...
# 428  Agricultural Production Foodgrains Coarse Cere...
#
#                            Frequency    Unit 1993 1994 1995 1996 1997 1998  \
# 0    Annual, Ending mar Of Each Year  Ton mn
# 1    Annual, Ending mar Of Each Year  Ton mn
# 2    Annual, Ending mar Of Each Year  Ton mn
# 3    Annual, Ending mar Of Each Year  Ton mn
# ...

# %%
df.drop(columns='Frequency', inplace=True)
df
# Out:
#                                            Particulars    Unit 1993 1994 1995  \
# 0                   Agricultural Production Foodgrains  Ton mn
# 1            Agricultural Production Foodgrains Kharif  Ton mn
# 2              Agricultural Production Foodgrains Rabi  Ton mn
# 3              Agricultural Production Foodgrains Rice  Ton mn
# 4       Agricultural Production Foodgrains Rice Kharif  Ton mn
# ..                                                 ...     ...  ...  ...  ...
# 424  Agricultural Production Foodgrains Coarse Cere...   kg/ha
# 425  Agricultural Production Foodgrains Coarse Cere...   kg/ha
# 426  Agricultural Production Foodgrains Coarse Cere...   kg/ha
# 427  Agricultural Production Foodgrains Coarse Cere...   kg/ha
# 428  Agricultural Production Foodgrains Coarse Cere...   kg/ha
#
#     1996 1997 1998 1999 2000  ...    2005    2006    2007    2008    2009  \
# 0                             ...  198.36  208.60  217.28  230.78  234.47
# ...

# %%
df1= df.set_index('Particulars')
df1
# Out:
#                                                       Unit 1993 1994 1995  \
# Particulars
# Agricultural Production Foodgrains                  Ton mn
# Agricultural Production Foodgrains Kharif           Ton mn
# Agricultural Production Foodgrains Rabi             Ton mn
# Agricultural Production Foodgrains Rice             Ton mn
# Agricultural Production Foodgrains Rice Kharif      Ton mn
# ...                                                    ...  ...  ...  ...
# Agricultural Production Foodgrains Coarse Cerea...   kg/ha
# Agricultural Production Foodgrains Coarse Cerea...   kg/ha
# Agricultural Production Foodgrains Coarse Cerea...   kg/ha
# Agricultural Production Foodgrains Coarse Cerea...   kg/ha
# Agricultural Production Foodgrains Coarse Cerea...   kg/ha
#
#                                                    1996 1997 1998 1999 2000  \
# Particulars
# Agricultural Production Foodgrains
# Agricultural Production Foodgrains Kharif
# Agricultural Production Foodgrains Rabi
# ...

# %%
# Data sorting and Vizualization

# %%
df2=df1[df1['Unit'].str.contains('Ton mn')]
df2
# Out:
#                                                       Unit 1993 1994 1995  \
# Particulars
# Agricultural Production Foodgrains                  Ton mn
# Agricultural Production Foodgrains Kharif           Ton mn
# Agricultural Production Foodgrains Rabi             Ton mn
# Agricultural Production Foodgrains Rice             Ton mn
# Agricultural Production Foodgrains Rice Kharif      Ton mn
# ...                                                    ...  ...  ...  ...
# Agricultural Production Foodgrains Volume West ...  Ton mn
# Agricultural Production Foodgrains Volume Others    Ton mn
# Agricultural Production Foodgrains Rice Volume      Ton mn
# Agricultural Production Foodgrains Wheat Volume     Ton mn
# Agricultural Production Foodgrains Coarse Cerea...  Ton mn
#
#                                                    1996 1997 1998 1999 2000  \
# Particulars
# Agricultural Production Foodgrains
# Agricultural Production Foodgrains Kharif
# Agricultural Production Foodgrains Rabi
# ...

# %%
df3=df1[df1['Unit'].str.contains('kg/ha')]
df3
# Out:
#                                                      Unit 1993 1994 1995 1996  \
# Particulars
# Agricultural Production Yield                       kg/ha
# Agricultural Production Kharif Yield                kg/ha
# Agricultural Production Rabi Yield                  kg/ha
# Agriculture Production Foodgrains Yield Foodgra...  kg/ha
# Agriculture Production Foodgrains Yield Foodgra...  kg/ha
# ...                                                   ...  ...  ...  ...  ...
# Agricultural Production Foodgrains Coarse Cerea...  kg/ha
# Agricultural Production Foodgrains Coarse Cerea...  kg/ha
# Agricultural Production Foodgrains Coarse Cerea...  kg/ha
# Agricultural Production Foodgrains Coarse Cerea...  kg/ha
# Agricultural Production Foodgrains Coarse Cerea...  kg/ha
#
#                                                    1997 1998 1999 2000 2001  \
# Particulars
# Agricultural Production Yield
# Agricultural Production Kharif Yield
# Agricultural Production Rabi Yield
# ...

# %%
# G1=df2[df2['Particulars'].str.contains('Agricultural Production Foodgrains')]
G1=df2.filter(['Agricultural Production Foodgrains'], axis=0)
G1
# Out:
#                                       Unit 1993 1994 1995 1996 1997 1998 1999  \
# Particulars
# Agricultural Production Foodgrains  Ton mn
#
#                                    2000 2001  ...   2005   2006   2007   2008  \
# Particulars                                   ...
# Agricultural Production Foodgrains            ... 198.36 208.60 217.28 230.78
#
#                                      2009   2010   2011   2012   2013   2014
# Particulars
# Agricultural Production Foodgrains 234.47 218.11 244.49 259.29 257.13 264.38
#
# [1 rows x 23 columns]

# %%
# G1.plot(kind='line', title='Foodgrains', xlabel='years', ylabel='Production', c='red')
G1.drop(columns=['Unit','1993','1994','1995','1996','1997','1998','1999','2000','2001','2002','2003','2004'], inplace=True)
G1
# Out:
#                                      2005   2006   2007   2008   2009   2010  \
# Particulars
# Agricultural Production Foodgrains 198.36 208.60 217.28 230.78 234.47 218.11
#
#                                      2011   2012   2013   2014
# Particulars
# Agricultural Production Foodgrains 244.49 259.29 257.13 264.38

# %%
G1.transpose().plot(kind='line', title='Foodgrains', xlabel='years', ylabel='Production (Ton mn)', c='Green')
# Out:
# <AxesSubplot: title={'center': 'Foodgrains'}, xlabel='years', ylabel='Production (Ton mn)'>

# %%
G1.transpose().plot.barh()
# Out:
# <AxesSubplot: >
